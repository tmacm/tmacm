# %%
import matplotlib.pyplot as plt
appointment_dates = ['01/23/19', '02/13/19', '03/06/19', '05/10/19', '02/07/20', '02/21/20', '05/29/20', '01/22/21', '03/01/21', '01/19/21']
luna_weight = [6.7, 10, 10, 15, 22.6, 23.6, 23.6, 24.9, 24.9, 27.2]
plt.xticks(rotation=90)
plt.plot(appointment_dates,luna_weight)
plt.show()

# %%
import matplotlib.pyplot as plt
appointment_dates = ['01/23/19', '02/13/19', '03/06/19', '05/10/19', '02/07/20', '02/21/20', '05/29/20', '01/22/21', '03/01/21', '01/19/21']
luna_weight = [6.7, 10, 10, 15, 22.6, 23.6, 23.6, 24.9, 24.9, 27.2]
plt.xticks(rotation=90)
plt.bar(appointment_dates,luna_weight)
plt.show()
